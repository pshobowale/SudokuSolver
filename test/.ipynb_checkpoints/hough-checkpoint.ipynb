# %%
import cv2 as cv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.rc('image', cmap='gray')

# %%
Org=cv.imread("Samples/1.jpg")
Org=cv.resize(Org,(400,round(Org.shape[0]/Org.shape[1]*400)))
I=cv.cvtColor(Org,cv.COLOR_RGB2GRAY)
I= cv.GaussianBlur(I,(7,7),0)
I= cv.Canny(I,50,150,apertureSize = 3)
I=-(I-np.max(I))
#I=cv.colorChange()
I= cv.GaussianBlur(I,(13,13),0)

# %%
plt.imshow(I)
plt.colorbar()

# %%
def drawline(I,p1,p2,val=255):

    dy = p2[0] - p1[0];
    dx = p2[1] - p1[1];


    step=dy
    if np.abs(dx)>np.abs(dy):
        step=dx


    #print(step)
    incX = dx/step
    incY = dy/step
    #print(incX,incY)
    
    y =yi= p1[0]
    x =xi= p1[1]

    if(step>0):
        for i in range(step+1):
            #print(xi,yi)
            I[xi,yi]=val
            x += incX;
            y += incY;
    
            xi,yi=np.round(x),np.round(y)
            xi,yi=np.int(xi),np.int(yi)
        
    
    else:
        y =yi= p2[0]
        x =xi= p2[1]
        for i in range(step,1):
            #print(xi,yi)
            I[xi,yi]=val
            x += incX;
            y += incY;
    
            xi,yi=np.round(x),np.round(y)
            xi,yi=np.int(xi),np.int(yi)

I=np.zeros((110,110))
drawline(I,(20,100),(100,3))

plt.imshow(I)

# %%
def line_energy(I,p1,p2):
    energy=0
    dy = p2[0] - p1[0];
    dx = p2[1] - p1[1];


    step=dy
    if np.abs(dx)>np.abs(dy):
        step=dx


    #print(step)
    incX = dx/step
    incY = dy/step
    #print(incX,incY)
    
    y =yi= p1[0]
    x =xi= p1[1]

    if(step>0):
        for i in range(step+1):
            #print(xi,yi)
            energy+=I[xi,yi]
            x += incX;
            y += incY;
    
            xi,yi=np.round(x),np.round(y)
            xi,yi=np.int(xi),np.int(yi)
        
    
    else:
        y =yi= p2[0]
        x =xi= p2[1]
        for i in range(step,1):
            #print(xi,yi)
            energy+=I[xi,yi]
            x += incX;
            y += incY;
    
            xi,yi=np.round(x),np.round(y)
            xi,yi=np.int(xi),np.int(yi)
            
    return energy/(np.max(I)*sq_distance((0,0),I.shape))

    
def sq_distance(p1,p2):
    if (p1[0]-p2[0])*(p1[0]-p2[0])+(p1[1]-p2[1])*(p1[1]-p2[1]):
        return sqrt((p1[0]-p2[0])*(p1[0]-p2[0])+(p1[1]-p2[1])*(p1[1]-p2[1]))
    else:
        return 0.5

def e_func(p1,p2,I):
    return line_energy(I,p1,p2)+1/sq_distance(p1,p2)

# %%
s1,s2=(0,9),(100,100)
I=np.ones((110,110))*255

drawline(I,(0,0),(100,100),0)
print(1000*e_func(s1,s2,I))

example=np.zeros((10,10))

for i in range(10,0,-1):
    print()
    for j in range(10,0,-1):
        print("%.2f" % e_func(I,(j,i),s2),i,j,end="|")
        example[i-1,j-1]=e_func(I,(j,i),s2)
    
drawline(I,s1,s2,200)
#plt.imshow(I)
plt.matshow(example,cmap="Pastel1")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-7e7fa5943527> in <module>
#       3
#       4 drawline(I,(0,0),(100,100),0)
# ----> 5 print(1000*e_func(s1,s2,I))
#       6
#       7 example=np.zeros((10,10))
#
# <ipython-input-94-69ce6f6f6705> in e_func(I, p1, p2)
#      51
#      52 def e_func(I,p1,p2):
# ---> 53     return line_energy(p1,p2,I)+1/sq_distance(p1,p2)
#
# <ipython-input-94-69ce6f6f6705> in line_energy(p1, p2, I)
#       6
#       7     step=dy
# ----> 8     if np.abs(dx)>np.abs(dy):
#       9         step=dx
#      10     print(p1,p2)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
I=np.ones((110,110))*255
drawline(I,(0,0),(100,100),0)

from scipy.optimize import minimize
from scipy.optimize import Bounds

bounds = Bounds([0, 0], [I.shape[1], I.shape[0]])
